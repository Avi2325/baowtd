# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
# Load data
df = pd.read_csv("data/train_1.csv/train_1.csv")
df.head()
# Out:
#                                                 Page  2015-07-01  2015-07-02  \
# 0            2NE1_zh.wikipedia.org_all-access_spider        18.0        11.0
# 1             2PM_zh.wikipedia.org_all-access_spider        11.0        14.0
# 2              3C_zh.wikipedia.org_all-access_spider         1.0         0.0
# 3         4minute_zh.wikipedia.org_all-access_spider        35.0        13.0
# 4  52_Hz_I_Love_You_zh.wikipedia.org_all-access_s...         NaN         NaN
#
#    2015-07-03  2015-07-04  2015-07-05  2015-07-06  2015-07-07  2015-07-08  \
# 0         5.0        13.0        14.0         9.0         9.0        22.0
# 1        15.0        18.0        11.0        13.0        22.0        11.0
# 2         1.0         1.0         0.0         4.0         0.0         3.0
# 3        10.0        94.0         4.0        26.0        14.0         9.0
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#    2015-07-09  ...  2016-12-22  2016-12-23  2016-12-24  2016-12-25  \
# 0        26.0  ...        32.0        63.0        15.0        26.0
# 1        10.0  ...        17.0        42.0        28.0        15.0
# 2         4.0  ...         3.0         1.0         1.0         7.0
# 3        11.0  ...        32.0        10.0        26.0        27.0
# 4         NaN  ...        48.0         9.0        25.0        13.0
#
#    2016-12-26  2016-12-27  2016-12-28  2016-12-29  2016-12-30  2016-12-31
# 0        14.0        20.0        22.0        19.0        18.0        20.0
# 1         9.0        30.0        52.0        45.0        26.0        20.0
# 2         4.0         4.0         6.0         3.0         4.0        17.0
# 3        16.0        11.0        17.0        19.0        10.0        11.0
# 4         3.0        11.0        27.0        13.0        36.0        10.0
#
# [5 rows x 551 columns]

# %% [markdown]
# ## Interchanging Rows and Column of data to get it in proper time series format

# %%
# Transpose rows and columns
df = df.T
df.head()
# Out:
#                                              0       \
# Page        2NE1_zh.wikipedia.org_all-access_spider
# 2015-07-01                                     18.0
# 2015-07-02                                     11.0
# 2015-07-03                                      5.0
# 2015-07-04                                     13.0
#
#                                             1       \
# Page        2PM_zh.wikipedia.org_all-access_spider
# 2015-07-01                                    11.0
# 2015-07-02                                    14.0
# 2015-07-03                                    15.0
# 2015-07-04                                    18.0
#
#                                            2       \
# Page        3C_zh.wikipedia.org_all-access_spider
# 2015-07-01                                    1.0
# 2015-07-02                                    0.0
# 2015-07-03                                    1.0
# 2015-07-04                                    1.0
#
#                                                 3       \
# Page        4minute_zh.wikipedia.org_all-access_spider
# 2015-07-01                                        35.0
# 2015-07-02                                        13.0
# 2015-07-03                                        10.0
# 2015-07-04                                        94.0
#
#                                                        4       \
# Page        52_Hz_I_Love_You_zh.wikipedia.org_all-access_s...
# 2015-07-01                                                NaN
# 2015-07-02                                                NaN
# 2015-07-03                                                NaN
# 2015-07-04                                                NaN
#
#                                              5       \
# Page        5566_zh.wikipedia.org_all-access_spider
# 2015-07-01                                     12.0
# 2015-07-02                                      7.0
# 2015-07-03                                      4.0
# 2015-07-04                                      5.0
#
#                                                6       \
# Page        91Days_zh.wikipedia.org_all-access_spider
# 2015-07-01                                        NaN
# 2015-07-02                                        NaN
# 2015-07-03                                        NaN
# 2015-07-04                                        NaN
#
#                                               7       \
# Page        A'N'D_zh.wikipedia.org_all-access_spider
# 2015-07-01                                     118.0
# 2015-07-02                                      26.0
# 2015-07-03                                      30.0
# 2015-07-04                                      24.0
#
#                                               8       \
# Page        AKB48_zh.wikipedia.org_all-access_spider
# 2015-07-01                                       5.0
# 2015-07-02                                      23.0
# 2015-07-03                                      14.0
# 2015-07-04                                      12.0
#
#                                               9       ...  \
# Page        ASCII_zh.wikipedia.org_all-access_spider  ...
# 2015-07-01                                       6.0  ...
# 2015-07-02                                       3.0  ...
# 2015-07-03                                       5.0  ...
# 2015-07-04                                      12.0  ...
#
#                                                        145053  \
# Page        Drake_(músico)_es.wikipedia.org_all-access_spider
# 2015-07-01                                                NaN
# 2015-07-02                                                NaN
# 2015-07-03                                                NaN
# 2015-07-04                                                NaN
#
#                                                        145054  \
# Page        Skam_(serie_de_televisión)_es.wikipedia.org_al...
# 2015-07-01                                                NaN
# 2015-07-02                                                NaN
# 2015-07-03                                                NaN
# 2015-07-04                                                NaN
#
#                                                        145055  \
# Page        Legión_(serie_de_televisión)_es.wikipedia.org_...
# 2015-07-01                                                NaN
# 2015-07-02                                                NaN
# 2015-07-03                                                NaN
# 2015-07-04                                                NaN
#
#                                                        145056  \
# Page        Doble_tentación_es.wikipedia.org_all-access_sp...
# 2015-07-01                                                NaN
# 2015-07-02                                                NaN
# 2015-07-03                                                NaN
# 2015-07-04                                                NaN
#
#                                                        145057  \
# Page        Mi_adorable_maldición_es.wikipedia.org_all-acc...
# 2015-07-01                                                NaN
# 2015-07-02                                                NaN
# 2015-07-03                                                NaN
# 2015-07-04                                                NaN
#
#                                                        145058  \
# Page        Underworld_(serie_de_películas)_es.wikipedia.o...
# 2015-07-01                                                NaN
# 2015-07-02                                                NaN
# 2015-07-03                                                NaN
# 2015-07-04                                                NaN
#
#                                                        145059  \
# Page        Resident_Evil:_Capítulo_Final_es.wikipedia.org...
# 2015-07-01                                                NaN
# 2015-07-02                                                NaN
# 2015-07-03                                                NaN
# 2015-07-04                                                NaN
#
#                                                        145060  \
# Page        Enamorándome_de_Ramón_es.wikipedia.org_all-acc...
# 2015-07-01                                                NaN
# 2015-07-02                                                NaN
# 2015-07-03                                                NaN
# 2015-07-04                                                NaN
#
#                                                        145061  \
# Page        Hasta_el_último_hombre_es.wikipedia.org_all-ac...
# 2015-07-01                                                NaN
# 2015-07-02                                                NaN
# 2015-07-03                                                NaN
# 2015-07-04                                                NaN
#
#                                                        145062
# Page        Francisco_el_matemático_(serie_de_televisión_d...
# 2015-07-01                                                NaN
# 2015-07-02                                                NaN
# 2015-07-03                                                NaN
# 2015-07-04                                                NaN
#
# [5 rows x 145063 columns]

# %%
df = df.reset_index()
df.head()
# Out:
#         index                                        0  \
# 0        Page  2NE1_zh.wikipedia.org_all-access_spider
# 1  2015-07-01                                     18.0
# 2  2015-07-02                                     11.0
# 3  2015-07-03                                      5.0
# 4  2015-07-04                                     13.0
#
#                                         1  \
# 0  2PM_zh.wikipedia.org_all-access_spider
# 1                                    11.0
# 2                                    14.0
# 3                                    15.0
# 4                                    18.0
#
#                                        2  \
# 0  3C_zh.wikipedia.org_all-access_spider
# 1                                    1.0
# 2                                    0.0
# 3                                    1.0
# 4                                    1.0
#
#                                             3  \
# 0  4minute_zh.wikipedia.org_all-access_spider
# 1                                        35.0
# 2                                        13.0
# 3                                        10.0
# 4                                        94.0
#
#                                                    4  \
# 0  52_Hz_I_Love_You_zh.wikipedia.org_all-access_s...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                          5  \
# 0  5566_zh.wikipedia.org_all-access_spider
# 1                                     12.0
# 2                                      7.0
# 3                                      4.0
# 4                                      5.0
#
#                                            6  \
# 0  91Days_zh.wikipedia.org_all-access_spider
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#                                           7  \
# 0  A'N'D_zh.wikipedia.org_all-access_spider
# 1                                     118.0
# 2                                      26.0
# 3                                      30.0
# 4                                      24.0
#
#                                           8  ...  \
# 0  AKB48_zh.wikipedia.org_all-access_spider  ...
# 1                                       5.0  ...
# 2                                      23.0  ...
# 3                                      14.0  ...
# 4                                      12.0  ...
#
#                                               145053  \
# 0  Drake_(músico)_es.wikipedia.org_all-access_spider
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                               145054  \
# 0  Skam_(serie_de_televisión)_es.wikipedia.org_al...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                               145055  \
# 0  Legión_(serie_de_televisión)_es.wikipedia.org_...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                               145056  \
# 0  Doble_tentación_es.wikipedia.org_all-access_sp...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                               145057  \
# 0  Mi_adorable_maldición_es.wikipedia.org_all-acc...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                               145058  \
# 0  Underworld_(serie_de_películas)_es.wikipedia.o...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                               145059  \
# 0  Resident_Evil:_Capítulo_Final_es.wikipedia.org...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                               145060  \
# 0  Enamorándome_de_Ramón_es.wikipedia.org_all-acc...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                               145061  \
# 0  Hasta_el_último_hombre_es.wikipedia.org_all-ac...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                               145062
# 0  Francisco_el_matemático_(serie_de_televisión_d...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 145064 columns]

# %%
# Capture 1st rows of data and make it column header
column_header = df.iloc[0,:].values

df.columns = column_header

# %%
df.head()
# Out:
#          Page  2NE1_zh.wikipedia.org_all-access_spider  \
# 0        Page  2NE1_zh.wikipedia.org_all-access_spider
# 1  2015-07-01                                     18.0
# 2  2015-07-02                                     11.0
# 3  2015-07-03                                      5.0
# 4  2015-07-04                                     13.0
#
#    2PM_zh.wikipedia.org_all-access_spider  \
# 0  2PM_zh.wikipedia.org_all-access_spider
# 1                                    11.0
# 2                                    14.0
# 3                                    15.0
# 4                                    18.0
#
#    3C_zh.wikipedia.org_all-access_spider  \
# 0  3C_zh.wikipedia.org_all-access_spider
# 1                                    1.0
# 2                                    0.0
# 3                                    1.0
# 4                                    1.0
#
#    4minute_zh.wikipedia.org_all-access_spider  \
# 0  4minute_zh.wikipedia.org_all-access_spider
# 1                                        35.0
# 2                                        13.0
# 3                                        10.0
# 4                                        94.0
#
#   52_Hz_I_Love_You_zh.wikipedia.org_all-access_spider  \
# 0  52_Hz_I_Love_You_zh.wikipedia.org_all-access_s...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    5566_zh.wikipedia.org_all-access_spider  \
# 0  5566_zh.wikipedia.org_all-access_spider
# 1                                     12.0
# 2                                      7.0
# 3                                      4.0
# 4                                      5.0
#
#    91Days_zh.wikipedia.org_all-access_spider  \
# 0  91Days_zh.wikipedia.org_all-access_spider
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#    A'N'D_zh.wikipedia.org_all-access_spider  \
# 0  A'N'D_zh.wikipedia.org_all-access_spider
# 1                                     118.0
# 2                                      26.0
# 3                                      30.0
# 4                                      24.0
#
#    AKB48_zh.wikipedia.org_all-access_spider  ...  \
# 0  AKB48_zh.wikipedia.org_all-access_spider  ...
# 1                                       5.0  ...
# 2                                      23.0  ...
# 3                                      14.0  ...
# 4                                      12.0  ...
#
#    Drake_(músico)_es.wikipedia.org_all-access_spider  \
# 0  Drake_(músico)_es.wikipedia.org_all-access_spider
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Skam_(serie_de_televisión)_es.wikipedia.org_all-access_spider  \
# 0  Skam_(serie_de_televisión)_es.wikipedia.org_al...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Legión_(serie_de_televisión)_es.wikipedia.org_all-access_spider  \
# 0  Legión_(serie_de_televisión)_es.wikipedia.org_...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Doble_tentación_es.wikipedia.org_all-access_spider  \
# 0  Doble_tentación_es.wikipedia.org_all-access_sp...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Mi_adorable_maldición_es.wikipedia.org_all-access_spider  \
# 0  Mi_adorable_maldición_es.wikipedia.org_all-acc...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Underworld_(serie_de_películas)_es.wikipedia.org_all-access_spider  \
# 0  Underworld_(serie_de_películas)_es.wikipedia.o...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Resident_Evil:_Capítulo_Final_es.wikipedia.org_all-access_spider  \
# 0  Resident_Evil:_Capítulo_Final_es.wikipedia.org...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Enamorándome_de_Ramón_es.wikipedia.org_all-access_spider  \
# 0  Enamorándome_de_Ramón_es.wikipedia.org_all-acc...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Hasta_el_último_hombre_es.wikipedia.org_all-access_spider  \
# 0  Hasta_el_último_hombre_es.wikipedia.org_all-ac...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Francisco_el_matemático_(serie_de_televisión_de_2017)_es.wikipedia.org_all-access_spider
# 0  Francisco_el_matemático_(serie_de_televisión_d...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 145064 columns]

# %%
# Drop 1st row
df = df.drop(0, axis = 0)

# %%
df.head()
# Out:
#          Page 2NE1_zh.wikipedia.org_all-access_spider  \
# 1  2015-07-01                                    18.0
# 2  2015-07-02                                    11.0
# 3  2015-07-03                                     5.0
# 4  2015-07-04                                    13.0
# 5  2015-07-05                                    14.0
#
#   2PM_zh.wikipedia.org_all-access_spider  \
# 1                                   11.0
# 2                                   14.0
# 3                                   15.0
# 4                                   18.0
# 5                                   11.0
#
#   3C_zh.wikipedia.org_all-access_spider  \
# 1                                   1.0
# 2                                   0.0
# 3                                   1.0
# 4                                   1.0
# 5                                   0.0
#
#   4minute_zh.wikipedia.org_all-access_spider  \
# 1                                       35.0
# 2                                       13.0
# 3                                       10.0
# 4                                       94.0
# 5                                        4.0
#
#   52_Hz_I_Love_You_zh.wikipedia.org_all-access_spider  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#   5566_zh.wikipedia.org_all-access_spider  \
# 1                                    12.0
# 2                                     7.0
# 3                                     4.0
# 4                                     5.0
# 5                                    20.0
#
#   91Days_zh.wikipedia.org_all-access_spider  \
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
#
#   A'N'D_zh.wikipedia.org_all-access_spider  \
# 1                                    118.0
# 2                                     26.0
# 3                                     30.0
# 4                                     24.0
# 5                                     29.0
#
#   AKB48_zh.wikipedia.org_all-access_spider  ...  \
# 1                                      5.0  ...
# 2                                     23.0  ...
# 3                                     14.0  ...
# 4                                     12.0  ...
# 5                                      9.0  ...
#
#   Drake_(músico)_es.wikipedia.org_all-access_spider  \
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# 5                                               NaN
#
#   Skam_(serie_de_televisión)_es.wikipedia.org_all-access_spider  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#   Legión_(serie_de_televisión)_es.wikipedia.org_all-access_spider  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#   Doble_tentación_es.wikipedia.org_all-access_spider  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#   Mi_adorable_maldición_es.wikipedia.org_all-access_spider  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#   Underworld_(serie_de_películas)_es.wikipedia.org_all-access_spider  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#   Resident_Evil:_Capítulo_Final_es.wikipedia.org_all-access_spider  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#   Enamorándome_de_Ramón_es.wikipedia.org_all-access_spider  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#   Hasta_el_último_hombre_es.wikipedia.org_all-access_spider  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#   Francisco_el_matemático_(serie_de_televisión_de_2017)_es.wikipedia.org_all-access_spider
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
# [5 rows x 145064 columns]

# %%
# Rename Page column to Date column
df = df.rename(columns = {"Page" : "Date"})

df.head()
# Out:
#          Date 2NE1_zh.wikipedia.org_all-access_spider  \
# 1  2015-07-01                                    18.0
# 2  2015-07-02                                    11.0
# 3  2015-07-03                                     5.0
# 4  2015-07-04                                    13.0
# 5  2015-07-05                                    14.0
#
#   2PM_zh.wikipedia.org_all-access_spider  \
# 1                                   11.0
# 2                                   14.0
# 3                                   15.0
# 4                                   18.0
# 5                                   11.0
#
#   3C_zh.wikipedia.org_all-access_spider  \
# 1                                   1.0
# 2                                   0.0
# 3                                   1.0
# 4                                   1.0
# 5                                   0.0
#
#   4minute_zh.wikipedia.org_all-access_spider  \
# 1                                       35.0
# 2                                       13.0
# 3                                       10.0
# 4                                       94.0
# 5                                        4.0
#
#   52_Hz_I_Love_You_zh.wikipedia.org_all-access_spider  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#   5566_zh.wikipedia.org_all-access_spider  \
# 1                                    12.0
# 2                                     7.0
# 3                                     4.0
# 4                                     5.0
# 5                                    20.0
#
#   91Days_zh.wikipedia.org_all-access_spider  \
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
#
#   A'N'D_zh.wikipedia.org_all-access_spider  \
# 1                                    118.0
# 2                                     26.0
# 3                                     30.0
# 4                                     24.0
# 5                                     29.0
#
#   AKB48_zh.wikipedia.org_all-access_spider  ...  \
# 1                                      5.0  ...
# 2                                     23.0  ...
# 3                                     14.0  ...
# 4                                     12.0  ...
# 5                                      9.0  ...
#
#   Drake_(músico)_es.wikipedia.org_all-access_spider  \
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# 5                                               NaN
#
#   Skam_(serie_de_televisión)_es.wikipedia.org_all-access_spider  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#   Legión_(serie_de_televisión)_es.wikipedia.org_all-access_spider  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#   Doble_tentación_es.wikipedia.org_all-access_spider  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#   Mi_adorable_maldición_es.wikipedia.org_all-access_spider  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#   Underworld_(serie_de_películas)_es.wikipedia.org_all-access_spider  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#   Resident_Evil:_Capítulo_Final_es.wikipedia.org_all-access_spider  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#   Enamorándome_de_Ramón_es.wikipedia.org_all-access_spider  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#   Hasta_el_último_hombre_es.wikipedia.org_all-access_spider  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#   Francisco_el_matemático_(serie_de_televisión_de_2017)_es.wikipedia.org_all-access_spider
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
# [5 rows x 145064 columns]

# %%
# Check data type of date column
print(df["Date"].dtype)
# Out:
# object

# %%
# Convert Date column to datetime datatype
df["Date"] = pd.to_datetime(df["Date"])

# %%
# Check Date column datatype again
print(df["Date"].dtype)
# Out:
# datetime64[ns]

# %%
# Set Date column as index
df = df.set_index("Date")

# %%
df.head()
# Out:
#            2NE1_zh.wikipedia.org_all-access_spider  \
# Date
# 2015-07-01                                    18.0
# 2015-07-02                                    11.0
# 2015-07-03                                     5.0
# 2015-07-04                                    13.0
# 2015-07-05                                    14.0
#
#            2PM_zh.wikipedia.org_all-access_spider  \
# Date
# 2015-07-01                                   11.0
# 2015-07-02                                   14.0
# 2015-07-03                                   15.0
# 2015-07-04                                   18.0
# 2015-07-05                                   11.0
#
#            3C_zh.wikipedia.org_all-access_spider  \
# Date
# 2015-07-01                                   1.0
# 2015-07-02                                   0.0
# 2015-07-03                                   1.0
# 2015-07-04                                   1.0
# 2015-07-05                                   0.0
#
#            4minute_zh.wikipedia.org_all-access_spider  \
# Date
# 2015-07-01                                       35.0
# 2015-07-02                                       13.0
# 2015-07-03                                       10.0
# 2015-07-04                                       94.0
# 2015-07-05                                        4.0
#
#            52_Hz_I_Love_You_zh.wikipedia.org_all-access_spider  \
# Date
# 2015-07-01                                                NaN
# 2015-07-02                                                NaN
# 2015-07-03                                                NaN
# 2015-07-04                                                NaN
# 2015-07-05                                                NaN
#
#            5566_zh.wikipedia.org_all-access_spider  \
# Date
# 2015-07-01                                    12.0
# 2015-07-02                                     7.0
# 2015-07-03                                     4.0
# 2015-07-04                                     5.0
# 2015-07-05                                    20.0
#
#            91Days_zh.wikipedia.org_all-access_spider  \
# Date
# 2015-07-01                                       NaN
# 2015-07-02                                       NaN
# 2015-07-03                                       NaN
# 2015-07-04                                       NaN
# 2015-07-05                                       NaN
#
#            A'N'D_zh.wikipedia.org_all-access_spider  \
# Date
# 2015-07-01                                    118.0
# 2015-07-02                                     26.0
# 2015-07-03                                     30.0
# 2015-07-04                                     24.0
# 2015-07-05                                     29.0
#
#            AKB48_zh.wikipedia.org_all-access_spider  \
# Date
# 2015-07-01                                      5.0
# 2015-07-02                                     23.0
# 2015-07-03                                     14.0
# 2015-07-04                                     12.0
# 2015-07-05                                      9.0
#
#            ASCII_zh.wikipedia.org_all-access_spider  ...  \
# Date                                                 ...
# 2015-07-01                                      6.0  ...
# 2015-07-02                                      3.0  ...
# 2015-07-03                                      5.0  ...
# 2015-07-04                                     12.0  ...
# 2015-07-05                                      6.0  ...
#
#            Drake_(músico)_es.wikipedia.org_all-access_spider  \
# Date
# 2015-07-01                                               NaN
# 2015-07-02                                               NaN
# 2015-07-03                                               NaN
# 2015-07-04                                               NaN
# 2015-07-05                                               NaN
#
#            Skam_(serie_de_televisión)_es.wikipedia.org_all-access_spider  \
# Date
# 2015-07-01                                                NaN
# 2015-07-02                                                NaN
# 2015-07-03                                                NaN
# 2015-07-04                                                NaN
# 2015-07-05                                                NaN
#
#            Legión_(serie_de_televisión)_es.wikipedia.org_all-access_spider  \
# Date
# 2015-07-01                                                NaN
# 2015-07-02                                                NaN
# 2015-07-03                                                NaN
# 2015-07-04                                                NaN
# 2015-07-05                                                NaN
#
#            Doble_tentación_es.wikipedia.org_all-access_spider  \
# Date
# 2015-07-01                                                NaN
# 2015-07-02                                                NaN
# 2015-07-03                                                NaN
# 2015-07-04                                                NaN
# 2015-07-05                                                NaN
#
#            Mi_adorable_maldición_es.wikipedia.org_all-access_spider  \
# Date
# 2015-07-01                                                NaN
# 2015-07-02                                                NaN
# 2015-07-03                                                NaN
# 2015-07-04                                                NaN
# 2015-07-05                                                NaN
#
#            Underworld_(serie_de_películas)_es.wikipedia.org_all-access_spider  \
# Date
# 2015-07-01                                                NaN
# 2015-07-02                                                NaN
# 2015-07-03                                                NaN
# 2015-07-04                                                NaN
# 2015-07-05                                                NaN
#
#            Resident_Evil:_Capítulo_Final_es.wikipedia.org_all-access_spider  \
# Date
# 2015-07-01                                                NaN
# 2015-07-02                                                NaN
# 2015-07-03                                                NaN
# 2015-07-04                                                NaN
# 2015-07-05                                                NaN
#
#            Enamorándome_de_Ramón_es.wikipedia.org_all-access_spider  \
# Date
# 2015-07-01                                                NaN
# 2015-07-02                                                NaN
# 2015-07-03                                                NaN
# 2015-07-04                                                NaN
# 2015-07-05                                                NaN
#
#            Hasta_el_último_hombre_es.wikipedia.org_all-access_spider  \
# Date
# 2015-07-01                                                NaN
# 2015-07-02                                                NaN
# 2015-07-03                                                NaN
# 2015-07-04                                                NaN
# 2015-07-05                                                NaN
#
#            Francisco_el_matemático_(serie_de_televisión_de_2017)_es.wikipedia.org_all-access_spider
# Date
# 2015-07-01                                                NaN
# 2015-07-02                                                NaN
# 2015-07-03                                                NaN
# 2015-07-04                                                NaN
# 2015-07-05                                                NaN
#
# [5 rows x 145063 columns]

# %% [markdown]
# Now the data is in proper time series format.

# %% [markdown]
# ## Splitting data based on different access types and different agents.

# %%
# Finding number of access types and agents
access_types = []
agents = []
for column in df.columns:
    access_type = column.split("_")[-2]
    agent = column.split("_")[-1]
    access_types.append(access_type)
    agents.append(agent)

# %%
# Counting access types
from collections import Counter
access_dict = Counter(access_types)
access_dict
# Out:
# Counter({'all-access': 74315, 'mobile-web': 35939, 'desktop': 34809})

# %%
print("Number of topics with all-access type:", access_dict["all-access"])
print("Number of topics with desktop access:", access_dict["desktop"])
print("Number of topics with mobile-web access:", access_dict["mobile-web"])
# Out:
# Number of topics with all-access type: 74315
# Number of topics with desktop access: 34809
# Number of topics with mobile-web access: 35939

# %%
access_df = pd.DataFrame({"Access type" : access_dict.keys(),
                          "Number of columns" : access_dict.values()})
access_df
# Out:
#   Access type  Number of columns
# 0  all-access              74315
# 1     desktop              34809
# 2  mobile-web              35939

# %%
# Counting agents
agents_dict = Counter(agents)
agents_dict
# Out:
# Counter({'all-agents': 110150, 'spider': 34913})

# %%
print("Number of topics with spider as agent:", agents_dict["spider"])
print("Number of topics with all-agents as agent:", agents_dict["all-agents"])
# Out:
# Number of topics with spider as agent: 34913
# Number of topics with all-agents as agent: 110150

# %%
agents_df = pd.DataFrame({"Agent" : agents_dict.keys(),
                          "Number of columns" : agents_dict.values()})
agents_df
# Out:
#         Agent  Number of columns
# 0      spider              34913
# 1  all-agents             110150

# %%
# Identifying number of columns with null values with respect to access type
def count_null_columns(pattern):
    pattern_columns = [column for column in df.columns if pattern in column]
    return len(df[pattern_columns].isnull().sum()[df[pattern_columns].isnull().sum() > 0])

no_of_cols_with_nulls = [count_null_columns(access_type) for access_type in access_df["Access type"]]

access_df["No of columns with nulls"] = no_of_cols_with_nulls

access_df
# Out:
#   Access type  Number of columns  No of columns with nulls
# 0  all-access              74315                     14808
# 1     desktop              34809                      6647
# 2  mobile-web              35939                      6331

# %%
# Identifying number of columns with null values with respect to agents
def count_null_columns(pattern):
    pattern_columns = [column for column in df.columns if pattern in column]
    return len(df[pattern_columns].isnull().sum()[df[pattern_columns].isnull().sum() > 0])

no_of_cols_with_nulls = [count_null_columns(agent) for agent in agents_df["Agent"]]

agents_df["No of columns with nulls"] = no_of_cols_with_nulls

agents_df
# Out:
#         Agent  Number of columns  No of columns with nulls
# 0      spider              34913                      5904
# 1  all-agents             110150                     21882

# %%
# Calculating percentage of null values in access types
access_df["% of nulls"] = access_df["No of columns with nulls"] / access_df["Number of columns"] * 100

access_df
# Out:
#   Access type  Number of columns  No of columns with nulls  % of nulls
# 0  all-access              74315                     14808   19.925991
# 1     desktop              34809                      6647   19.095636
# 2  mobile-web              35939                      6331   17.615960

# %% [markdown]
# Percentage of missing values in each access type is almost same. So there is no pattern in missing values.

# %%
# Calculating percentage of null values in agents
agents_df["% of nulls"] = agents_df["No of columns with nulls"] / agents_df["Number of columns"] * 100

agents_df
# Out:
#         Agent  Number of columns  No of columns with nulls  % of nulls
# 0      spider              34913                      5904   16.910606
# 1  all-agents             110150                     21882   19.865638

# %% [markdown]
# Percentae of missing values is almost same with each agents. So there is no pattern in missing values.

# %% [markdown]
# ## Splitting data based on different projects (like 'en.wikipedia.org')

# %%
df.columns[86543].split("_")[-3:]
# Out:
# ['ja.wikipedia.org', 'desktop', 'all-agents']

# %%
"_".join(df.columns[86543].split("_")[-3:])
# Out:
# 'ja.wikipedia.org_desktop_all-agents'

# %%
df.columns[86543]
# Out:
# '種田梨沙_ja.wikipedia.org_desktop_all-agents'

# %%
projects = []
for column in df.columns:
    project = column.split("_")[-3] # Extracting language code from column name (topic name)
    projects.append(project)

# %%
project_dict = Counter(projects)
project_dict
# Out:
# Counter({'en.wikipedia.org': 24108,
#          'ja.wikipedia.org': 20431,
#          'de.wikipedia.org': 18547,
#          'fr.wikipedia.org': 17802,
#          'zh.wikipedia.org': 17229,
#          'ru.wikipedia.org': 15022,
#          'es.wikipedia.org': 14069,
#          'commons.wikimedia.org': 10555,
#          'www.mediawiki.org': 7300})

# %%
project_df = pd.DataFrame({"Project" : project_dict.keys(),
                           "Number of columns" : project_dict.values()})

project_df
# Out:
#                  Project  Number of columns
# 0       zh.wikipedia.org              17229
# 1       fr.wikipedia.org              17802
# 2       en.wikipedia.org              24108
# 3  commons.wikimedia.org              10555
# 4       ru.wikipedia.org              15022
# 5      www.mediawiki.org               7300
# 6       de.wikipedia.org              18547
# 7       ja.wikipedia.org              20431
# 8       es.wikipedia.org              14069

# %%
# Identifying number of columns with null values with respect to projects
def count_null_columns(pattern):
    pattern_columns = [column for column in df.columns if pattern in column]
    return len(df[pattern_columns].isnull().sum()[df[pattern_columns].isnull().sum() > 0])

no_of_cols_with_nulls = [count_null_columns(project) for project in project_df["Project"]]

project_df["No of columns with nulls"] = no_of_cols_with_nulls

project_df#3
# Out:
#                  Project  Number of columns  No of columns with nulls
# 0       zh.wikipedia.org              17229                      4039
# 1       fr.wikipedia.org              17802                      2012
# 2       en.wikipedia.org              24108                      5811
# 3  commons.wikimedia.org              10555                      5149
# 4       ru.wikipedia.org              15022                      1573
# 5      www.mediawiki.org               7300                      3534
# 6       de.wikipedia.org              18547                      2368
# 7       ja.wikipedia.org              20431                      2030
# 8       es.wikipedia.org              14069                      1270

# %%
# Calculating percentage of null values
project_df["% of nulls"] = project_df["No of columns with nulls"] / project_df["Number of columns"] * 100

project_df#2
# Out:
#                  Project  Number of columns  No of columns with nulls  \
# 0       zh.wikipedia.org              17229                      4039
# 1       fr.wikipedia.org              17802                      2012
# 2       en.wikipedia.org              24108                      5811
# 3  commons.wikimedia.org              10555                      5149
# 4       ru.wikipedia.org              15022                      1573
# 5      www.mediawiki.org               7300                      3534
# 6       de.wikipedia.org              18547                      2368
# 7       ja.wikipedia.org              20431                      2030
# 8       es.wikipedia.org              14069                      1270
#
#    % of nulls
# 0   23.443032
# 1   11.302101
# 2   24.104032
# 3   48.782568
# 4   10.471309
# 5   48.410959
# 6   12.767563
# 7    9.935882
# 8    9.026939

# %%
project_df.sort_values(by = "% of nulls", ascending = False)#1
# Out:
#                  Project  Number of columns  No of columns with nulls  \
# 3  commons.wikimedia.org              10555                      5149
# 5      www.mediawiki.org               7300                      3534
# 2       en.wikipedia.org              24108                      5811
# 0       zh.wikipedia.org              17229                      4039
# 6       de.wikipedia.org              18547                      2368
# 1       fr.wikipedia.org              17802                      2012
# 4       ru.wikipedia.org              15022                      1573
# 7       ja.wikipedia.org              20431                      2030
# 8       es.wikipedia.org              14069                      1270
#
#    % of nulls
# 3   48.782568
# 5   48.410959
# 2   24.104032
# 0   23.443032
# 6   12.767563
# 1   11.302101
# 4   10.471309
# 7    9.935882
# 8    9.026939

# %% [markdown]
# columns with projects commons.wikimedia.org and www.mediawiki.org have 48% columns with null values

# %%
df.columns
# Out:
# Index(['2NE1_zh.wikipedia.org_all-access_spider',
#        '2PM_zh.wikipedia.org_all-access_spider',
#        '3C_zh.wikipedia.org_all-access_spider',
#        '4minute_zh.wikipedia.org_all-access_spider',
#        '52_Hz_I_Love_You_zh.wikipedia.org_all-access_spider',
#        '5566_zh.wikipedia.org_all-access_spider',
#        '91Days_zh.wikipedia.org_all-access_spider',
#        'A'N'D_zh.wikipedia.org_all-access_spider',
#        'AKB48_zh.wikipedia.org_all-access_spider',
#        'ASCII_zh.wikipedia.org_all-access_spider',
#        ...
#        'Drake_(músico)_es.wikipedia.org_all-access_spider',
#        'Skam_(serie_de_televisión)_es.wikipedia.org_all-access_spider',
#        'Legión_(serie_de_televisión)_es.wikipedia.org_all-access_spider',
#        'Doble_tentación_es.wikipedia.org_all-access_spider',
#        'Mi_adorable_maldición_es.wikipedia.org_all-access_spider',
#        'Underworld_(serie_de_películas)_es.wikipedia.org_all-access_spider',
#        'Resident_Evil:_Capítulo_Final_es.wikipedia.org_all-access_spider',
#        'Enamorándome_de_Ramón_es.wikipedia.org_all-access_spider',
#        'Hasta_el_último_hombre_es.wikipedia.org_all-access_spider',
#        'Francisco_el_matemático_(serie_de_televisión_de_2017)_es.wikipedia.org_all-access_spider'],
#       dtype='object', length=145063)

# %%
required_column_names = [column for column in df.columns if "commons.wikimedia.org" in column]

# %%
df[required_column_names].sum().mean()
# Out:
# 99429.18484130743

# %%
df[required_column_names]
# Out:
#            Accueil_commons.wikimedia.org_all-access_spider  \
# Date
# 2015-07-01                                            55.0
# 2015-07-02                                            48.0
# 2015-07-03                                            44.0
# 2015-07-04                                            35.0
# 2015-07-05                                            46.0
# ...                                                    ...
# 2016-12-27                                            57.0
# 2016-12-28                                            74.0
# 2016-12-29                                            61.0
# 2016-12-30                                            51.0
# 2016-12-31                                            60.0
#
#            Atlas_of_Asia_commons.wikimedia.org_all-access_spider  \
# Date
# 2015-07-01                                                5.0
# 2015-07-02                                                3.0
# 2015-07-03                                                4.0
# 2015-07-04                                                6.0
# 2015-07-05                                                3.0
# ...                                                       ...
# 2016-12-27                                               29.0
# 2016-12-28                                               37.0
# 2016-12-29                                               32.0
# 2016-12-30                                               29.0
# 2016-12-31                                               34.0
#
#            Atlas_of_Europe_commons.wikimedia.org_all-access_spider  \
# Date
# 2015-07-01                                                4.0
# 2015-07-02                                                6.0
# 2015-07-03                                                9.0
# 2015-07-04                                                7.0
# 2015-07-05                                                6.0
# ...                                                       ...
# 2016-12-27                                               31.0
# 2016-12-28                                               31.0
# 2016-12-29                                               34.0
# 2016-12-30                                               28.0
# 2016-12-31                                               27.0
#
#            Atlas_of_World_War_II_commons.wikimedia.org_all-access_spider  \
# Date
# 2015-07-01                                                5.0
# 2015-07-02                                                2.0
# 2015-07-03                                                6.0
# 2015-07-04                                                6.0
# 2015-07-05                                                8.0
# ...                                                       ...
# 2016-12-27                                                8.0
# 2016-12-28                                               13.0
# 2016-12-29                                                5.0
# 2016-12-30                                               11.0
# 2016-12-31                                                6.0
#
#            Atlas_of_colonialism_commons.wikimedia.org_all-access_spider  \
# Date
# 2015-07-01                                                8.0
# 2015-07-02                                                6.0
# 2015-07-03                                               15.0
# 2015-07-04                                                5.0
# 2015-07-05                                                5.0
# ...                                                       ...
# 2016-12-27                                               19.0
# 2016-12-28                                               30.0
# 2016-12-29                                               29.0
# 2016-12-30                                               26.0
# 2016-12-31                                               26.0
#
#            Atlas_of_the_United_Kingdom_commons.wikimedia.org_all-access_spider  \
# Date
# 2015-07-01                                                5.0
# 2015-07-02                                                7.0
# 2015-07-03                                                6.0
# 2015-07-04                                               10.0
# 2015-07-05                                                7.0
# ...                                                       ...
# 2016-12-27                                               21.0
# 2016-12-28                                               13.0
# 2016-12-29                                               27.0
# 2016-12-30                                               12.0
# 2016-12-31                                                8.0
#
#            Atlas_of_the_United_States_commons.wikimedia.org_all-access_spider  \
# Date
# 2015-07-01                                               10.0
# 2015-07-02                                               14.0
# 2015-07-03                                               13.0
# 2015-07-04                                               20.0
# 2015-07-05                                                9.0
# ...                                                       ...
# 2016-12-27                                               49.0
# 2016-12-28                                               10.0
# 2016-12-29                                               14.0
# 2016-12-30                                               17.0
# 2016-12-31                                               12.0
#
#            Bikini_commons.wikimedia.org_all-access_spider  \
# Date
# 2015-07-01                                            4.0
# 2015-07-02                                            5.0
# 2015-07-03                                            2.0
# 2015-07-04                                            2.0
# 2015-07-05                                            2.0
# ...                                                   ...
# 2016-12-27                                            4.0
# 2016-12-28                                            5.0
# 2016-12-29                                            7.0
# 2016-12-30                                            8.0
# 2016-12-31                                            4.0
#
#            Campaign:OFBA2016_commons.wikimedia.org_all-access_spider  \
# Date
# 2015-07-01                                                NaN
# 2015-07-02                                                NaN
# 2015-07-03                                                NaN
# 2015-07-04                                                NaN
# 2015-07-05                                                NaN
# ...                                                       ...
# 2016-12-27                                                2.0
# 2016-12-28                                                3.0
# 2016-12-29                                                2.0
# 2016-12-30                                                2.0
# 2016-12-31                                                4.0
#
#            Catalogue_of_Wilhelm_von_Gloeden's_pictures_commons.wikimedia.org_all-access_spider  \
# Date
# 2015-07-01                                                3.0
# 2015-07-02                                                4.0
# 2015-07-03                                                5.0
# 2015-07-04                                                2.0
# 2015-07-05                                                3.0
# ...                                                       ...
# 2016-12-27                                                5.0
# 2016-12-28                                               12.0
# 2016-12-29                                               81.0
# 2016-12-30                                                8.0
# 2016-12-31                                                7.0
#
#             ...  \
# Date        ...
# 2015-07-01  ...
# 2015-07-02  ...
# 2015-07-03  ...
# 2015-07-04  ...
# 2015-07-05  ...
# ...         ...
# 2016-12-27  ...
# 2016-12-28  ...
# 2016-12-29  ...
# 2016-12-30  ...
# 2016-12-31  ...
#
#            File:Artist’s_impression_of_the_ultracool_dwarf_star_TRAPPIST-1_from_close_to_one_of_its_planets.ogv_commons.wikimedia.org_desktop_all-agents  \
# Date
# 2015-07-01                                                NaN
# 2015-07-02                                                NaN
# 2015-07-03                                                NaN
# 2015-07-04                                                NaN
# 2015-07-05                                                NaN
# ...                                                       ...
# 2016-12-27                                                6.0
# 2016-12-28                                               10.0
# 2016-12-29                                                8.0
# 2016-12-30                                                7.0
# 2016-12-31                                                7.0
#
#            File:Torm_detsembris._Merivälja_Muul.jpg_commons.wikimedia.org_desktop_all-agents  \
# Date
# 2015-07-01                                                NaN
# 2015-07-02                                                NaN
# 2015-07-03                                                NaN
# 2015-07-04                                                NaN
# 2015-07-05                                                NaN
# ...                                                       ...
# 2016-12-27                                               20.0
# 2016-12-28                                               24.0
# 2016-12-29                                               23.0
# 2016-12-30                                               14.0
# 2016-12-31                                               25.0
#
#            File:Talv_Väike-Taevaskojas.jpg_commons.wikimedia.org_desktop_all-agents  \
# Date
# 2015-07-01                                                NaN
# 2015-07-02                                                NaN
# 2015-07-03                                                NaN
# 2015-07-04                                                NaN
# 2015-07-05                                                NaN
# ...                                                       ...
# 2016-12-27                                                4.0
# 2016-12-28                                               12.0
# 2016-12-29                                                4.0
# 2016-12-30                                               11.0
# 2016-12-31                                                5.0
#
#            Category:2016_Turkish_coup_d'état_attempt_commons.wikimedia.org_desktop_all-agents  \
# Date
# 2015-07-01                                                NaN
# 2015-07-02                                                NaN
# 2015-07-03                                                NaN
# 2015-07-04                                                NaN
# 2015-07-05                                                NaN
# ...                                                       ...
# 2016-12-27                                                9.0
# 2016-12-28                                               15.0
# 2016-12-29                                                5.0
# 2016-12-30                                                8.0
# 2016-12-31                                                7.0
#
#            File:Pokémon_Go_Release_Map.svg_commons.wikimedia.org_desktop_all-agents  \
# Date
# 2015-07-01                                                NaN
# 2015-07-02                                                NaN
# 2015-07-03                                                NaN
# 2015-07-04                                                NaN
# 2015-07-05                                                NaN
# ...                                                       ...
# 2016-12-27                                                9.0
# 2016-12-28                                               12.0
# 2016-12-29                                               11.0
# 2016-12-30                                                3.0
# 2016-12-31                                                3.0
#
#            Commons:Уики_обича_паметниците_2016_България_commons.wikimedia.org_desktop_all-agents  \
# Date
# 2015-07-01                                                NaN
# 2015-07-02                                                NaN
# 2015-07-03                                                NaN
# 2015-07-04                                                NaN
# 2015-07-05                                                NaN
# ...                                                       ...
# 2016-12-27                                                3.0
# 2016-12-28                                                3.0
# 2016-12-29                                                4.0
# 2016-12-30                                                1.0
# 2016-12-31                                                1.0
#
#            File:Landgericht_Berlin,_Littenstraße,_Eingangshalle_(2),_160906,_ako.jpg_commons.wikimedia.org_desktop_all-agents  \
# Date
# 2015-07-01                                                NaN
# 2015-07-02                                                NaN
# 2015-07-03                                                NaN
# 2015-07-04                                                NaN
# 2015-07-05                                                NaN
# ...                                                       ...
# 2016-12-27                                               31.0
# 2016-12-28                                               27.0
# 2016-12-29                                               31.0
# 2016-12-30                                               26.0
# 2016-12-31                                               27.0
#
#            File:Battle_of_Mosul_(2016–2017).svg_commons.wikimedia.org_desktop_all-agents  \
# Date
# 2015-07-01                                                NaN
# 2015-07-02                                                NaN
# 2015-07-03                                                NaN
# 2015-07-04                                                NaN
# 2015-07-05                                                NaN
# ...                                                       ...
# 2016-12-27                                                NaN
# 2016-12-28                                                NaN
# 2016-12-29                                                NaN
# 2016-12-30                                                NaN
# 2016-12-31                                                NaN
#
#            File:Ура!.ogv_commons.wikimedia.org_desktop_all-agents  \
# Date
# 2015-07-01                                                NaN
# 2015-07-02                                                NaN
# 2015-07-03                                                NaN
# 2015-07-04                                                NaN
# 2015-07-05                                                NaN
# ...                                                       ...
# 2016-12-27                                                NaN
# 2016-12-28                                                NaN
# 2016-12-29                                                NaN
# 2016-12-30                                                NaN
# 2016-12-31                                                NaN
#
#            File:関東地方居住者の自治体別四年制大学卒業率.png_commons.wikimedia.org_desktop_all-agents
# Date
# 2015-07-01                                                NaN
# 2015-07-02                                                NaN
# 2015-07-03                                                NaN
# 2015-07-04                                                NaN
# 2015-07-05                                                NaN
# ...                                                       ...
# 2016-12-27                                                NaN
# 2016-12-28                                                NaN
# 2016-12-29                                                NaN
# 2016-12-30                                                NaN
# 2016-12-31                                                NaN
#
# [550 rows x 10555 columns]

# %%
project_df["Project"]
# Out:
# 0         zh.wikipedia.org
# 1         fr.wikipedia.org
# 2         en.wikipedia.org
# 3    commons.wikimedia.org
# 4         ru.wikipedia.org
# 5        www.mediawiki.org
# 6         de.wikipedia.org
# 7         ja.wikipedia.org
# 8         es.wikipedia.org
# Name: Project, dtype: object

# %%
def extract_total_views(project):
    required_column_names = [column for column in df.columns if project in column]
    total_views = df[required_column_names].sum().sum()
    return total_views

# %%
total_views = []
for project in project_df["Project"]:
    total_views.append(extract_total_views(project))
    
total_views
# Out:
# [3171985333.0,
#  6377823517.0,
#  58748760323.0,
#  1049475046.0,
#  7998365818.0,
#  229304903.0,
#  8862013751.0,
#  8571290162.0,
#  9490200499.0]

# %%
project_df["Total views"] = total_views
project_df#5
# Out:
#                  Project  Number of columns  No of columns with nulls  \
# 0       zh.wikipedia.org              17229                      4039
# 1       fr.wikipedia.org              17802                      2012
# 2       en.wikipedia.org              24108                      5811
# 3  commons.wikimedia.org              10555                      5149
# 4       ru.wikipedia.org              15022                      1573
# 5      www.mediawiki.org               7300                      3534
# 6       de.wikipedia.org              18547                      2368
# 7       ja.wikipedia.org              20431                      2030
# 8       es.wikipedia.org              14069                      1270
#
#    % of nulls   Total views
# 0   23.443032  3.171985e+09
# 1   11.302101  6.377824e+09
# 2   24.104032  5.874876e+10
# 3   48.782568  1.049475e+09
# 4   10.471309  7.998366e+09
# 5   48.410959  2.293049e+08
# 6   12.767563  8.862014e+09
# 7    9.935882  8.571290e+09
# 8    9.026939  9.490200e+09

# %%
def extract_average_views(project):
    required_column_names = [column for column in df.columns if project in column]
    average_views = df[required_column_names].sum().mean()
    return average_views

# %%
average_views = []
for project in project_df["Project"]:
    average_views.append(extract_average_views(project))
    
average_views
# Out:
# [184107.33838295896,
#  358264.4375351084,
#  2436898.968101875,
#  99429.18484130743,
#  532443.4707761949,
#  31411.630547945206,
#  477813.86482989165,
#  419523.7708384318,
#  674546.9115786481]

# %%
project_df["Average views"] = average_views
project_df#6
# Out:
#                  Project  Number of columns  No of columns with nulls  \
# 0       zh.wikipedia.org              17229                      4039
# 1       fr.wikipedia.org              17802                      2012
# 2       en.wikipedia.org              24108                      5811
# 3  commons.wikimedia.org              10555                      5149
# 4       ru.wikipedia.org              15022                      1573
# 5      www.mediawiki.org               7300                      3534
# 6       de.wikipedia.org              18547                      2368
# 7       ja.wikipedia.org              20431                      2030
# 8       es.wikipedia.org              14069                      1270
#
#    % of nulls   Total views  Average views
# 0   23.443032  3.171985e+09   1.841073e+05
# 1   11.302101  6.377824e+09   3.582644e+05
# 2   24.104032  5.874876e+10   2.436899e+06
# 3   48.782568  1.049475e+09   9.942918e+04
# 4   10.471309  7.998366e+09   5.324435e+05
# 5   48.410959  2.293049e+08   3.141163e+04
# 6   12.767563  8.862014e+09   4.778139e+05
# 7    9.935882  8.571290e+09   4.195238e+05
# 8    9.026939  9.490200e+09   6.745469e+05

# %%
project_df['Total views'] = project_df['Total views'].astype('int64')
project_df['Average views'] = project_df['Average views'].astype('int64')
project_df
# Out:
#                  Project  Number of columns  No of columns with nulls  \
# 0       zh.wikipedia.org              17229                      4039
# 1       fr.wikipedia.org              17802                      2012
# 2       en.wikipedia.org              24108                      5811
# 3  commons.wikimedia.org              10555                      5149
# 4       ru.wikipedia.org              15022                      1573
# 5      www.mediawiki.org               7300                      3534
# 6       de.wikipedia.org              18547                      2368
# 7       ja.wikipedia.org              20431                      2030
# 8       es.wikipedia.org              14069                      1270
#
#    % of nulls  Total views  Average views
# 0   23.443032   3171985333         184107
# 1   11.302101   6377823517         358264
# 2   24.104032  58748760323        2436898
# 3   48.782568   1049475046          99429
# 4   10.471309   7998365818         532443
# 5   48.410959    229304903          31411
# 6   12.767563   8862013751         477813
# 7    9.935882   8571290162         419523
# 8    9.026939   9490200499         674546

# %%
project_df_sorted = project_df.sort_values(by = "Average views", ascending = False)
project_df_sorted
# Out:
#                  Project  Number of columns  No of columns with nulls  \
# 2       en.wikipedia.org              24108                      5811
# 8       es.wikipedia.org              14069                      1270
# 4       ru.wikipedia.org              15022                      1573
# 6       de.wikipedia.org              18547                      2368
# 7       ja.wikipedia.org              20431                      2030
# 1       fr.wikipedia.org              17802                      2012
# 0       zh.wikipedia.org              17229                      4039
# 3  commons.wikimedia.org              10555                      5149
# 5      www.mediawiki.org               7300                      3534
#
#    % of nulls  Total views  Average views
# 2   24.104032  58748760323        2436898
# 8    9.026939   9490200499         674546
# 4   10.471309   7998365818         532443
# 6   12.767563   8862013751         477813
# 7    9.935882   8571290162         419523
# 1   11.302101   6377823517         358264
# 0   23.443032   3171985333         184107
# 3   48.782568   1049475046          99429
# 5   48.410959    229304903          31411

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize = (10,6))
sns.barplot(x = project_df_sorted["Project"], y = project_df_sorted["Average views"])
plt.xticks(rotation = "vertical")
plt.title("Average views per each project")
plt.savefig('average_view_per_website.png')

# %% [markdown]
# ## Popular pages in "en.wikipedia.org"

# %%
en_wikipedia_org_columns = [column for column in df.columns if "en.wikipedia.org" in column]

top_pages_en = df[en_wikipedia_org_columns].mean().sort_values(ascending = False)[0:5]
top_pages_en
# Out:
# Main_Page_en.wikipedia.org_all-access_all-agents         21938511.094545
# Main_Page_en.wikipedia.org_desktop_all-agents            15953631.741818
# Main_Page_en.wikipedia.org_mobile-web_all-agents          5734517.967273
# Special:Search_en.wikipedia.org_all-access_all-agents     2371053.369091
# Special:Search_en.wikipedia.org_desktop_all-agents        1839723.178182
# dtype: object

# %%
df[top_pages_en.index].plot(figsize = (16,9))
plt.savefig('colourfull_graph.png')

# %% [markdown]
# ## Popular pages in "es.wikipedia.org"

# %%
es_wikipedia_org_columns = [column for column in df.columns if "es.wikipedia.org" in column]

top_pages_es = df[es_wikipedia_org_columns].mean().sort_values(ascending = False)[0:5]
top_pages_es
# Out:
# Wikipedia:Portada_es.wikipedia.org_all-access_all-agents    1366349.643636
# Wikipedia:Portada_es.wikipedia.org_mobile-web_all-agents    1027413.403636
# Especial:Buscar_es.wikipedia.org_all-access_all-agents       353620.445455
# Wikipedia:Portada_es.wikipedia.org_desktop_all-agents        300798.825455
# Especial:Buscar_es.wikipedia.org_desktop_all-agents              291693.22
# dtype: object

# %%
df[top_pages_es.index].plot(figsize = (16,9))
plt.savefig('popular_pages_below.png')

# %% [markdown]
# ## Popular pages in "ru.wikipedia.org"

# %%
ru_wikipedia_org_columns = [column for column in df.columns if "ru.wikipedia.org" in column]

top_pages_ru = df[ru_wikipedia_org_columns].mean().sort_values(ascending = False)[0:5]
top_pages_ru
# Out:
# Заглавная_страница_ru.wikipedia.org_all-access_all-agents    1974580.821818
# Заглавная_страница_ru.wikipedia.org_desktop_all-agents       1350690.938182
# Заглавная_страница_ru.wikipedia.org_mobile-web_all-agents     596237.150909
# Служебная:Поиск_ru.wikipedia.org_all-access_all-agents        188662.325455
# Служебная:Поиск_ru.wikipedia.org_desktop_all-agents           179389.401818
# dtype: object

# %%
df[top_pages_ru.index].plot(figsize = (16,9))
plt.savefig('popular_pages_2.png')

# %% [markdown]
# ## Popular pages in "de.wikipedia.org"

# %%
de_wikipedia_org_columns = [column for column in df.columns if "de.wikipedia.org" in column]

top_pages_de = df[de_wikipedia_org_columns].mean().sort_values(ascending = False)[0:5]
top_pages_de
# Out:
# Wikipedia:Hauptseite_de.wikipedia.org_all-access_all-agents    2916244.087273
# Wikipedia:Hauptseite_de.wikipedia.org_mobile-web_all-agents    2023071.061818
# Wikipedia:Hauptseite_de.wikipedia.org_desktop_all-agents        776349.865455
# Spezial:Suche_de.wikipedia.org_all-access_all-agents            406228.989091
# Spezial:Suche_de.wikipedia.org_desktop_all-agents               399339.565455
# dtype: object

# %%
df[top_pages_de.index].plot(figsize = (16,9))
plt.savefig('popular_pages_3.png')

# %% [markdown]
# ## Popular pages in "ja.wikipedia.org"

# %%
ja_wikipedia_org_columns = [column for column in df.columns if "ja.wikipedia.org" in column]

top_pages_ja = df[ja_wikipedia_org_columns].mean().sort_values(ascending = False)[0:5]
top_pages_ja
# Out:
# メインページ_ja.wikipedia.org_all-access_all-agents    383188.718182
# メインページ_ja.wikipedia.org_desktop_all-agents       243904.390909
# xss_ja.wikipedia.org_desktop_all-agents               138722.0
# 特別:検索_ja.wikipedia.org_all-access_all-agents     127848.961818
# 特別:検索_ja.wikipedia.org_desktop_all-agents        125845.829091
# dtype: object

# %%
df[top_pages_ja.index].plot(figsize = (16,9))
plt.savefig('popular_pages_4.png')
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_9336\3705257798.py:2: UserWarning: Glyph 12513 (\N{KATAKANA LETTER ME}) missing from current font.
#   plt.savefig('popular_pages_4.png')
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_9336\3705257798.py:2: UserWarning: Glyph 12452 (\N{KATAKANA LETTER I}) missing from current font.
#   plt.savefig('popular_pages_4.png')
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_9336\3705257798.py:2: UserWarning: Glyph 12531 (\N{KATAKANA LETTER N}) missing from current font.
#   plt.savefig('popular_pages_4.png')
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_9336\3705257798.py:2: UserWarning: Glyph 12506 (\N{KATAKANA LETTER PE}) missing from current font.
#   plt.savefig('popular_pages_4.png')
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_9336\3705257798.py:2: UserWarning: Glyph 12540 (\N{KATAKANA-HIRAGANA PROLONGED SOUND MARK}) missing from current font.
#   plt.savefig('popular_pages_4.png')
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_9336\3705257798.py:2: UserWarning: Glyph 12472 (\N{KATAKANA LETTER ZI}) missing from current font.
#   plt.savefig('popular_pages_4.png')
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_9336\3705257798.py:2: UserWarning: Glyph 29305 (\N{CJK UNIFIED IDEOGRAPH-7279}) missing from current font.
#   plt.savefig('popular_pages_4.png')
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_9336\3705257798.py:2: UserWarning: Glyph 21029 (\N{CJK UNIFIED IDEOGRAPH-5225}) missing from current font.
#   plt.savefig('popular_pages_4.png')
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_9336\3705257798.py:2: UserWarning: Glyph 26908 (\N{CJK UNIFIED IDEOGRAPH-691C}) missing from current font.
#   plt.savefig('popular_pages_4.png')
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_9336\3705257798.py:2: UserWarning: Glyph 32034 (\N{CJK UNIFIED IDEOGRAPH-7D22}) missing from current font.
#   plt.savefig('popular_pages_4.png')
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_9336\3705257798.py:2: UserWarning: Glyph 12513 (\N{KATAKANA LETTER ME}) missing from current font.
#   plt.savefig('popular_pages_4.png')
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_9336\3705257798.py:2: UserWarning: Glyph 12452 (\N{KATAKANA LETTER I}) missing from current font.
#   plt.savefig('popular_pages_4.png')
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_9336\3705257798.py:2: UserWarning: Glyph 12531 (\N{KATAKANA LETTER N}) missing from current font.
#   plt.savefig('popular_pages_4.png')
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_9336\3705257798.py:2: UserWarning: Glyph 12506 (\N{KATAKANA LETTER PE}) missing from current font.
#   plt.savefig('popular_pages_4.png')
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_9336\3705257798.py:2: UserWarning: Glyph 12540 (\N{KATAKANA-HIRAGANA PROLONGED SOUND MARK}) missing from current font.
#   plt.savefig('popular_pages_4.png')
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_9336\3705257798.py:2: UserWarning: Glyph 12472 (\N{KATAKANA LETTER ZI}) missing from current font.
#   plt.savefig('popular_pages_4.png')
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_9336\3705257798.py:2: UserWarning: Glyph 29305 (\N{CJK UNIFIED IDEOGRAPH-7279}) missing from current font.
#   plt.savefig('popular_pages_4.png')
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_9336\3705257798.py:2: UserWarning: Glyph 21029 (\N{CJK UNIFIED IDEOGRAPH-5225}) missing from current font.
#   plt.savefig('popular_pages_4.png')
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_9336\3705257798.py:2: UserWarning: Glyph 26908 (\N{CJK UNIFIED IDEOGRAPH-691C}) missing from current font.
#   plt.savefig('popular_pages_4.png')
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_9336\3705257798.py:2: UserWarning: Glyph 32034 (\N{CJK UNIFIED IDEOGRAPH-7D22}) missing from current font.
#   plt.savefig('popular_pages_4.png')
# c:\Users\ASUS\miniconda5\envs\project\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 12513 (\N{KATAKANA LETTER ME}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\ASUS\miniconda5\envs\project\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 12452 (\N{KATAKANA LETTER I}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\ASUS\miniconda5\envs\project\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 12531 (\N{KATAKANA LETTER N}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\ASUS\miniconda5\envs\project\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 12506 (\N{KATAKANA LETTER PE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\ASUS\miniconda5\envs\project\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 12540 (\N{KATAKANA-HIRAGANA PROLONGED SOUND MARK}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\ASUS\miniconda5\envs\project\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 12472 (\N{KATAKANA LETTER ZI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\ASUS\miniconda5\envs\project\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 29305 (\N{CJK UNIFIED IDEOGRAPH-7279}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\ASUS\miniconda5\envs\project\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 21029 (\N{CJK UNIFIED IDEOGRAPH-5225}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\ASUS\miniconda5\envs\project\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 26908 (\N{CJK UNIFIED IDEOGRAPH-691C}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\ASUS\miniconda5\envs\project\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 32034 (\N{CJK UNIFIED IDEOGRAPH-7D22}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## Popular pages in "fr.wikipedia.org"

# %%
fr_wikipedia_org_columns = [column for column in df.columns if "fr.wikipedia.org" in column]

top_pages_fr = df[fr_wikipedia_org_columns].mean().sort_values(ascending = False)[0:5]
top_pages_fr
# Out:
# Wikipédia:Accueil_principal_fr.wikipedia.org_all-access_all-agents    1579055.758182
# Wikipédia:Accueil_principal_fr.wikipedia.org_mobile-web_all-agents    1111459.674545
# Wikipédia:Accueil_principal_fr.wikipedia.org_desktop_all-agents        435616.385455
# Spécial:Recherche_fr.wikipedia.org_all-access_all-agents               173938.861818
# Spécial:Recherche_fr.wikipedia.org_desktop_all-agents                  160816.250909
# dtype: object

# %%
df[top_pages_fr.index].plot(figsize = (16,9))
plt.savefig('popular_pages_5.png')

# %% [markdown]
# ## Popular pages in "zh.wikipedia.org"

# %%
zh_wikipedia_org_columns = [column for column in df.columns if "zh.wikipedia.org" in column]

top_pages_zh = df[zh_wikipedia_org_columns].mean().sort_values(ascending = False)[0:5]
top_pages_zh
# Out:
# Wikipedia:首页_zh.wikipedia.org_all-access_all-agents    224898.749091
# Wikipedia:首页_zh.wikipedia.org_desktop_all-agents       120792.074545
# Wikipedia:首页_zh.wikipedia.org_mobile-web_all-agents     92522.598182
# Special:搜索_zh.wikipedia.org_all-access_all-agents           88505.68
# Special:搜索_zh.wikipedia.org_desktop_all-agents          87643.350909
# dtype: object

# %%
df[top_pages_zh.index].plot(figsize = (16,9))
plt.savefig('popular_pages_6.png')
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_9336\3530045016.py:2: UserWarning: Glyph 39318 (\N{CJK UNIFIED IDEOGRAPH-9996}) missing from current font.
#   plt.savefig('popular_pages_6.png')
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_9336\3530045016.py:2: UserWarning: Glyph 39029 (\N{CJK UNIFIED IDEOGRAPH-9875}) missing from current font.
#   plt.savefig('popular_pages_6.png')
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_9336\3530045016.py:2: UserWarning: Glyph 25628 (\N{CJK UNIFIED IDEOGRAPH-641C}) missing from current font.
#   plt.savefig('popular_pages_6.png')
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_9336\3530045016.py:2: UserWarning: Glyph 32034 (\N{CJK UNIFIED IDEOGRAPH-7D22}) missing from current font.
#   plt.savefig('popular_pages_6.png')
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_9336\3530045016.py:2: UserWarning: Glyph 39318 (\N{CJK UNIFIED IDEOGRAPH-9996}) missing from current font.
#   plt.savefig('popular_pages_6.png')
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_9336\3530045016.py:2: UserWarning: Glyph 39029 (\N{CJK UNIFIED IDEOGRAPH-9875}) missing from current font.
#   plt.savefig('popular_pages_6.png')
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_9336\3530045016.py:2: UserWarning: Glyph 25628 (\N{CJK UNIFIED IDEOGRAPH-641C}) missing from current font.
#   plt.savefig('popular_pages_6.png')
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_9336\3530045016.py:2: UserWarning: Glyph 32034 (\N{CJK UNIFIED IDEOGRAPH-7D22}) missing from current font.
#   plt.savefig('popular_pages_6.png')
# c:\Users\ASUS\miniconda5\envs\project\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 39318 (\N{CJK UNIFIED IDEOGRAPH-9996}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\ASUS\miniconda5\envs\project\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 39029 (\N{CJK UNIFIED IDEOGRAPH-9875}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\ASUS\miniconda5\envs\project\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 25628 (\N{CJK UNIFIED IDEOGRAPH-641C}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\ASUS\miniconda5\envs\project\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 32034 (\N{CJK UNIFIED IDEOGRAPH-7D22}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## Popular pages in "commons.wikipedia.org"

# %%
commons_wikipedia_org_columns = [column for column in df.columns if "commons.wikimedia.org" in column]

top_pages_commons = df[commons_wikipedia_org_columns].mean().sort_values(ascending = False)[0:5]
top_pages_commons
# Out:
# Special:CreateAccount_commons.wikimedia.org_all-access_all-agents    259881.091787
# Special:CreateAccount_commons.wikimedia.org_desktop_all-agents       232178.884058
# Special:Search_commons.wikimedia.org_all-access_all-agents           122092.069091
# Special:Search_commons.wikimedia.org_desktop_all-agents              115181.374545
# Main_Page_commons.wikimedia.org_all-access_all-agents                 95876.894545
# dtype: object

# %%
df[top_pages_commons.index].plot(figsize = (16,9))
plt.savefig('popular_pages_7.png')

# %% [markdown]
# ## Popular pages in "www.mediawiki.org"

# %%
mediawiki_org_columns = [column for column in df.columns if "www.mediawiki.org" in column]

top_pages_mediawiki = df[mediawiki_org_columns].mean().sort_values(ascending = False)[0:5]
top_pages_mediawiki
# Out:
# MediaWiki_www.mediawiki.org_all-access_all-agents                             31103.154545
# MediaWiki_www.mediawiki.org_desktop_all-agents                                24010.001818
# Special:CreateAccount_www.mediawiki.org_all-access_all-agents                 11767.389423
# Special:CreateAccount_www.mediawiki.org_desktop_all-agents                    11127.461538
# Special:MyLanguage/Help:Logging_in_www.mediawiki.org_all-access_all-agents     9019.054118
# dtype: object

# %%
df[top_pages_mediawiki.index].plot(figsize = (16,8))
plt.savefig('popular_pages_8.png')
